# %%
import lightkurve as lk

# %%
lcf = lk.search_targetpixelfile('AU Mic').download()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-560fe6e03971> in <module>
# ----> 1 lcf = lk.search_targetpixelfile('AU Mic').download()
#
# ~/anaconda3/lib/python3.7/site-packages/lightkurve/utils.py in wrapper(*args, **kwargs)
#     448             sys.stdout = devnull
#     449             try:
# --> 450                 return f(*args, **kwargs)
#     451             # restore to default
#     452             finally:
#
# ~/anaconda3/lib/python3.7/site-packages/lightkurve/search.py in download(self, quality_bitmask, download_dir, cutout_size)
#     172
#     173             # open() will determine filetype and return
# --> 174             return open(path, quality_bitmask=quality_bitmask)
#     175
#     176     @suppress_stdout
#
# ~/anaconda3/lib/python3.7/site-packages/lightkurve/search.py in open(path_or_url, **kwargs)
#     901     """
# ...

# %%
tpf = lk.TessTargetPixelFile('https://mast.stsci.edu/api/v0.1/Download/file/?uri=mast:TESS/product/tess2018206045859-s0001-0000000441420236-0120-s_tp.fits')#,

# %%
tpf.plot()

# %%
tpf = lk.search_targetpixelfile('AU Mic').download()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-074a4d2e3f39> in <module>
# ----> 1 tpf = lk.search_targetpixelfile('AU Mic').download()
#
# ~/anaconda3/lib/python3.7/site-packages/lightkurve/utils.py in wrapper(*args, **kwargs)
#     448             sys.stdout = devnull
#     449             try:
# --> 450                 return f(*args, **kwargs)
#     451             # restore to default
#     452             finally:
#
# ~/anaconda3/lib/python3.7/site-packages/lightkurve/search.py in download(self, quality_bitmask, download_dir, cutout_size)
#     172
#     173             # open() will determine filetype and return
# --> 174             return open(path, quality_bitmask=quality_bitmask)
#     175
#     176     @suppress_stdout
#
# ~/anaconda3/lib/python3.7/site-packages/lightkurve/search.py in open(path_or_url, **kwargs)
#     901     """
# ...

# %%
tpf = lk.search_targetpixelfile('L 98-59').download_all()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-e877f580b31f> in <module>
# ----> 1 tpf = lk.search_targetpixelfile('L 98-59').download_all()
#
# ~/anaconda3/lib/python3.7/site-packages/lightkurve/utils.py in wrapper(*args, **kwargs)
#     448             sys.stdout = devnull
#     449             try:
# --> 450                 return f(*args, **kwargs)
#     451             # restore to default
#     452             finally:
#
# ~/anaconda3/lib/python3.7/site-packages/lightkurve/search.py in download_all(self, quality_bitmask, download_dir, cutout_size)
#     236         lcf_extensions = ['llc.fits', 'slc.fits', '_lc.fits']
#     237         if any(e in self.table['productFilename'][0] for e in tpf_extensions):
# --> 238             return TargetPixelFileCollection([open(p, quality_bitmask=quality_bitmask) for p in path])
# ...
